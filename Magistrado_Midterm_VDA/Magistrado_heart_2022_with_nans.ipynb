# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

path="/content/drive/MyDrive/DataSet/heart_2022_with_nans.csv"
df= pd.read_csv(path, delimiter=',', header=0, encoding='utf-8') #Uses a comma as the column separator, Treat the first row as the header, use UTF-8 to support special characters
df
# Out:
#                  State     Sex GeneralHealth  PhysicalHealthDays  \
# 0              Alabama  Female     Very good                 0.0
# 1              Alabama  Female     Excellent                 0.0
# 2              Alabama  Female     Very good                 2.0
# 3              Alabama  Female     Excellent                 0.0
# 4              Alabama  Female          Fair                 2.0
# ...                ...     ...           ...                 ...
# 445127  Virgin Islands  Female          Good                 0.0
# 445128  Virgin Islands  Female     Excellent                 2.0
# 445129  Virgin Islands  Female          Poor                30.0
# 445130  Virgin Islands    Male     Very good                 0.0
# 445131  Virgin Islands    Male     Very good                 0.0
#
#         MentalHealthDays                                    LastCheckupTime  \
# 0                    0.0  Within past year (anytime less than 12 months ...
# ...

# %%
print (df.columns)
# Out:
# Index(['State', 'Sex', 'GeneralHealth', 'PhysicalHealthDays',
#        'MentalHealthDays', 'LastCheckupTime', 'PhysicalActivities',
#        'SleepHours', 'RemovedTeeth', 'HadHeartAttack', 'HadAngina',
#        'HadStroke', 'HadAsthma', 'HadSkinCancer', 'HadCOPD',
#        'HadDepressiveDisorder', 'HadKidneyDisease', 'HadArthritis',
#        'HadDiabetes', 'DeafOrHardOfHearing', 'BlindOrVisionDifficulty',
#        'DifficultyConcentrating', 'DifficultyWalking',
#        'DifficultyDressingBathing', 'DifficultyErrands', 'SmokerStatus',
#        'ECigaretteUsage', 'ChestScan', 'RaceEthnicityCategory', 'AgeCategory',
#        'HeightInMeters', 'WeightInKilograms', 'BMI', 'AlcoholDrinkers',
#        'HIVTesting', 'FluVaxLast12', 'PneumoVaxEver', 'TetanusLast10Tdap',
#        'HighRiskLastYear', 'CovidPos'],
#       dtype='object')

# %% [markdown]
# # **QUESTIONS**

# %% [markdown]
# 1. What data visualization would be the nost appropriate in determining the numebr of tested positive in HIV by sex?

# %%
hiv_positive_df = df[df['HIVTesting'] == 'Yes']

gender_hiv_counts = hiv_positive_df.groupby('Sex')['HIVTesting'].count()

plt.figure(figsize=(8, 8))
plt.pie(gender_hiv_counts, labels=gender_hiv_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('HIV Positivity by Gender')
plt.show()

# %% [markdown]
# **Observation** : The pie chart shows the percentage of individuals who tested positive for HIV based on their sex. It is revealed that women make up a larger percentage of HIV-positive (53.2%) than men (46.8%). According to this finding, women are more likely than men to test positive for HIV.

# %% [markdown]
# 2. What data visualization would be the most appropriate to use to represent the number of people with COVID-19 per state?

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(20, 10))
plt.bar(state_covid_counts.index, state_covid_counts.values, color='g')
plt.xlabel('State')
plt.ylabel('Number of People with COVID-19')
plt.title('Number of People with COVID-19 per State')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Observation**: The best way to visualize data is with a bar chart, which shows how many people in each state have COVID-19. According to the data, the number of COVID-19 cases varies greatly by state. COVID-19 is most common in Wyoming, Texas, and South Carolina while Virgin Islands, Virginia, and Puerto Rico are the states with the fewest COVID-19 cases.
